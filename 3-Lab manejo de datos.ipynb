# %%
# !pip install pandas
# !pip install numpy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 138.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 151.9 MB/s eta 0:00:00
# ...

# %%
# Pandas is a software library written for the Python programming language for data manipulation and analysis.
import pandas as pd
#NumPy is a library for the Python programming language, adding support for large, multi-dimensional arrays and matrices, along with a large collection of high-level mathematical functions to operate on these arrays
import numpy as np

# %%
df=pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/dataset_part_1.csv")
df.head(10)
# Out:
#    FlightNumber        Date BoosterVersion  PayloadMass Orbit    LaunchSite  \
# 0             1  2010-06-04       Falcon 9  6104.959412   LEO  CCAFS SLC 40
# 1             2  2012-05-22       Falcon 9   525.000000   LEO  CCAFS SLC 40
# 2             3  2013-03-01       Falcon 9   677.000000   ISS  CCAFS SLC 40
# 3             4  2013-09-29       Falcon 9   500.000000    PO   VAFB SLC 4E
# 4             5  2013-12-03       Falcon 9  3170.000000   GTO  CCAFS SLC 40
# 5             6  2014-01-06       Falcon 9  3325.000000   GTO  CCAFS SLC 40
# 6             7  2014-04-18       Falcon 9  2296.000000   ISS  CCAFS SLC 40
# 7             8  2014-07-14       Falcon 9  1316.000000   LEO  CCAFS SLC 40
# 8             9  2014-08-05       Falcon 9  4535.000000   GTO  CCAFS SLC 40
# 9            10  2014-09-07       Falcon 9  4428.000000   GTO  CCAFS SLC 40
#
#        Outcome  Flights  GridFins  Reused   Legs LandingPad  Block  \
# ...

# %%
df.isnull().sum()/len(df)*100
# Out:
# FlightNumber       0.000000
# Date               0.000000
# BoosterVersion     0.000000
# PayloadMass        0.000000
# Orbit              0.000000
# LaunchSite         0.000000
# Outcome            0.000000
# Flights            0.000000
# GridFins           0.000000
# Reused             0.000000
# Legs               0.000000
# LandingPad        28.888889
# Block              0.000000
# ReusedCount        0.000000
# Serial             0.000000
# Longitude          0.000000
# Latitude           0.000000
# dtype: float64

# %%
df.dtypes
# Out:
# FlightNumber        int64
# Date               object
# BoosterVersion     object
# PayloadMass       float64
# Orbit              object
# LaunchSite         object
# Outcome            object
# Flights             int64
# GridFins             bool
# Reused               bool
# Legs                 bool
# LandingPad         object
# Block             float64
# ReusedCount         int64
# Serial             object
# Longitude         float64
# Latitude          float64
# dtype: object

# %%
# Apply value_counts() on column LaunchSite

# %%
 
ccafs_launches = data[data['LaunchSite'] == 'CCAFS SLC 40']
print("Lanzamientos desde CCAFS SLC 40:", len(ccafs_launches))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 ccafs_launches = data[data['LaunchSite'] == 'CCAFS SLC 40']
#       2 print("Lanzamientos desde CCAFS SLC 40:", len(ccafs_launches))
#
# NameError: name 'data' is not defined

# %%
import pandas as pd

# Asegúrate de que el DataFrame 'data' ya esté cargado
# 1. Lanzamientos desde 'CCAFS SLC 40'
ccafs_launches = data[data['LaunchSite'] == 'CCAFS SLC 40']
print("Lanzamientos desde CCAFS SLC 40:", len(ccafs_launches))

# 2. Tasa de éxito
successes = ccafs_launches[ccafs_launches['Outcome'] == 'Success']
success_rate = len(successes) / len(ccafs_launches) * 100
print("Tasa de éxito:", round(success_rate, 2), "%")

# 3. Lanzamientos a órbita geosíncrona (GTO)
gto_launches = data[data['Orbit'] == 'GTO']
print("Lanzamientos a órbita geosíncrona (GTO):", len(gto_launches))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 5
#       1 import pandas as pd
#       3 # Asegúrate de que el DataFrame 'data' ya esté cargado
#       4 # 1. Lanzamientos desde 'CCAFS SLC 40'
# ----> 5 ccafs_launches = data[data['LaunchSite'] == 'CCAFS SLC 40']
#       6 print("Lanzamientos desde CCAFS SLC 40:", len(ccafs_launches))
#       8 # 2. Tasa de éxito
#
# NameError: name 'data' is not defined

# %%
 
# 1. Lanzamientos desde 'CCAFS SLC 40'
ccafs_launches = data[data['LaunchSite'] == 'CCAFS SLC 40']
print("Lanzamientos desde CCAFS SLC 40:", len(ccafs_launches))

# 2. Tasa de éxito
successes = ccafs_launches[ccafs_launches['Outcome'] == 'Success']
success_rate = len(successes) / len(ccafs_launches) * 100
print("Tasa de éxito:", round(success_rate, 2), "%")

# 3. Lanzamientos a órbita geosíncrona (GTO)
gto_launches = data[data['Orbit'] == 'GTO']
print("Lanzamientos a órbita geosíncrona (GTO):", len(gto_launches))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 # 1. Lanzamientos desde 'CCAFS SLC 40'
# ----> 2 ccafs_launches = data[data['LaunchSite'] == 'CCAFS SLC 40']
#       3 print("Lanzamientos desde CCAFS SLC 40:", len(ccafs_launches))
#       5 # 2. Tasa de éxito
#
# NameError: name 'data' is not defined

# %%
import pandas as pd

# Asegúrate de que el archivo esté cargado correctamente
# Por ejemplo:
# data = pd.read_csv('dataset_part_1.csv')

# 1. Lanzamientos desde 'CCAFS SLC 40'
ccafs_launches = data[data['LaunchSite'] == 'CCAFS SLC 40']
print("Lanzamientos desde CCAFS SLC 40:", len(ccafs_launches))

# 2. Tasa de éxito
successes = ccafs_launches[ccafs_launches['Outcome'] == 'Success']
success_rate = len(successes) / len(ccafs_launches) * 100
print("Tasa de éxito:", round(success_rate, 2), "%")

# 3. Lanzamientos a órbita geosíncrona (GTO)
gto_launches = data[data['Orbit'] == 'GTO']
print("Lanzamientos a órbita geosíncrona (GTO):", len(gto_launches))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 8
#       1 import pandas as pd
#       3 # Asegúrate de que el archivo esté cargado correctamente
#       4 # Por ejemplo:
#       5 # data = pd.read_csv('dataset_part_1.csv')
#       6
#       7 # 1. Lanzamientos desde 'CCAFS SLC 40'
# ----> 8 ccafs_launches = data[data['LaunchSite'] == 'CCAFS SLC 40']
#       9 print("Lanzamientos desde CCAFS SLC 40:", len(ccafs_launches))
#      11 # 2. Tasa de éxito
#
# NameError: name 'data' is not defined

# %%
df=pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/dataset_part_1.csv")
df.head(10)
# Out:
#    FlightNumber        Date BoosterVersion  PayloadMass Orbit    LaunchSite  \
# 0             1  2010-06-04       Falcon 9  6104.959412   LEO  CCAFS SLC 40
# 1             2  2012-05-22       Falcon 9   525.000000   LEO  CCAFS SLC 40
# 2             3  2013-03-01       Falcon 9   677.000000   ISS  CCAFS SLC 40
# 3             4  2013-09-29       Falcon 9   500.000000    PO   VAFB SLC 4E
# 4             5  2013-12-03       Falcon 9  3170.000000   GTO  CCAFS SLC 40
# 5             6  2014-01-06       Falcon 9  3325.000000   GTO  CCAFS SLC 40
# 6             7  2014-04-18       Falcon 9  2296.000000   ISS  CCAFS SLC 40
# 7             8  2014-07-14       Falcon 9  1316.000000   LEO  CCAFS SLC 40
# 8             9  2014-08-05       Falcon 9  4535.000000   GTO  CCAFS SLC 40
# 9            10  2014-09-07       Falcon 9  4428.000000   GTO  CCAFS SLC 40
#
#        Outcome  Flights  GridFins  Reused   Legs LandingPad  Block  \
# ...

# %%
 
import pandas as pd

# Cargar el archivo desde el enlace
data = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0321EN-SpaceX/labs/module_1_L2/dataset_part_1.csv")

# Verificar las primeras filas
print(data.head())
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[11], line 4
#       1 import pandas as pd
#       3 # Cargar el archivo desde el enlace
# ----> 4 data = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0321EN-SpaceX/labs/module_1_L2/dataset_part_1.csv")
#       6 # Verificar las primeras filas
#       7 print(data.head())
#
# ...

# %%
 
# Mostrar solo las columnas necesarias
print(data[['LaunchSite', 'Outcome', 'Orbit']])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 # Mostrar solo las columnas necesarias
# ----> 2 print(data[['LaunchSite', 'Outcome', 'Orbit']])
#
# NameError: name 'data' is not defined

# %%
 
import pandas as pd

# Si ya cargaste el archivo como 'data'
data['Date'] = pd.to_datetime(data['Date'], errors='coerce')
years = data['Date'].dt.year.dropna().unique()
print("Años cubiertos por el dataset:", sorted(years))

# %%
 
df[df['LaunchSite'] == 'CCAFS SLC 40'].shape[0]
# Out:
# 55

# %%
 
df[df['LaunchSite'] == 'CCAFS SLC 40'].shape[0]
# Out:
# 55

# %%
 
ccafs = df[df['LaunchSite'] == 'CCAFS SLC 40']
successes = ccafs[ccafs['Outcome'] == 'Success']
len(successes) / len(ccafs) * 100
# Out:
# 0.0

# %%
df['LaunchSite'].value_counts()
# Out:
# LaunchSite
# CCAFS SLC 40    55
# KSC LC 39A      22
# VAFB SLC 4E     13
# Name: count, dtype: int64

# %%
 
df['Orbit'].value_counts()
# Out:
#   Cell In[110], line 2
#
#     ^
# SyntaxError: invalid non-printable character U+00A0

# %%
 
# Ver todas las variantes de Outcome relacionadas con ASDS
print(df['Outcome'].value_counts())
# Out:
# Outcome
# True ASDS      41
# None None      19
# True RTLS      14
# False ASDS      6
# True Ocean      5
# False Ocean     2
# None ASDS       2
# False RTLS      1
# Name: count, dtype: int64

# %%
# Out:
#   Cell In[112], line 4
#
#     ^
# SyntaxError: invalid non-printable character U+00A0

# %%
df=pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/dataset_part_1.csv")
df.head(10)
# Out:
#    FlightNumber        Date BoosterVersion  PayloadMass Orbit    LaunchSite  \
# 0             1  2010-06-04       Falcon 9  6104.959412   LEO  CCAFS SLC 40
# 1             2  2012-05-22       Falcon 9   525.000000   LEO  CCAFS SLC 40
# 2             3  2013-03-01       Falcon 9   677.000000   ISS  CCAFS SLC 40
# 3             4  2013-09-29       Falcon 9   500.000000    PO   VAFB SLC 4E
# 4             5  2013-12-03       Falcon 9  3170.000000   GTO  CCAFS SLC 40
# 5             6  2014-01-06       Falcon 9  3325.000000   GTO  CCAFS SLC 40
# 6             7  2014-04-18       Falcon 9  2296.000000   ISS  CCAFS SLC 40
# 7             8  2014-07-14       Falcon 9  1316.000000   LEO  CCAFS SLC 40
# 8             9  2014-08-05       Falcon 9  4535.000000   GTO  CCAFS SLC 40
# 9            10  2014-09-07       Falcon 9  4428.000000   GTO  CCAFS SLC 40
#
#        Outcome  Flights  GridFins  Reused   Legs LandingPad  Block  \
# ...

# %%
df.isnull().sum()/len(df)*100

# %%
 
# Agrupar por tipo de órbita y resultado de misión
resultado_por_orbita = df.groupby(['Orbit', 'Outcome']).size().reset_index(name='Count')

# Mostrar la tabla
print(resultado_por_orbita)
# Out:
#     Orbit      Outcome  Count
# 0   ES-L1   True Ocean      1
# 1     GEO    True ASDS      1
# 2     GTO   False ASDS      1
# 3     GTO    None ASDS      1
# 4     GTO    None None     11
# 5     GTO    True ASDS     13
# 6     GTO   True Ocean      1
# 7     HEO    True ASDS      1
# 8     ISS   False ASDS      2
# 9     ISS  False Ocean      1
# 10    ISS   False RTLS      1
# 11    ISS    None ASDS      1
# 12    ISS    None None      3
# 13    ISS    True ASDS      5
# 14    ISS   True Ocean      1
# 15    ISS    True RTLS      7
# 16    LEO    None None      2
# 17    LEO   True Ocean      1
# 18    LEO    True RTLS      4
# 19    MEO    None None      1
# 20    MEO    True ASDS      2
# 21     PO   False ASDS      1
# 22     PO  False Ocean      1
# 23     PO    None None      1
# 24     PO    True ASDS      5
# 25     PO   True Ocean      1
# 26     SO    None None      1
# 27    SSO    True ASDS      2
# 28    SSO    True RTLS      3
# 29   VLEO   False ASDS      2
# ...

# %%
 
# Contar aterrizajes exitosos en naves no tripuladas (ASDS)
df['Outcome'].value_counts().get('True ASDS', 0)
# Out:
# np.int64(41)
